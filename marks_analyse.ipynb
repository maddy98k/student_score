# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Importing data and cleaning

# %% [markdown]
# *This dataset appears to be a collection of information about students and their academic performance, as well as various factors that may influence their performance.*

# %%
df=pd.read_csv("score marks.csv")
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
df.shape
# Out:
# (30641, 15)

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               30641 non-null  object
#  1   EthnicGroup          28801 non-null  object
#  2   ParentEduc           28796 non-null  object
#  3   LunchType            30641 non-null  object
#  4   TestPrep             28811 non-null  object
#  5   ParentMaritalStatus  29451 non-null  object
#  6   PracticeSport        30010 non-null  object
#  7   IsFirstChild         29737 non-null  object
#  8   NrSiblings           29069 non-null  float64
#  9   TransportMeans       27507 non-null  object
#  10  WklyStudyHours       29686 non-null  object
#  11  MathScore            30641 non-null  int64
#  12  ReadingScore         30641 non-null  int64
#  13  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 3.3+ MB

# %%
df.describe()
# Out:
#          NrSiblings     MathScore  ReadingScore  WritingScore
# count  29069.000000  30641.000000  30641.000000  30641.000000
# mean       2.145894     66.558402     69.377533     68.418622
# std        1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000     10.000000      4.000000
# 25%        1.000000     56.000000     59.000000     58.000000
# 50%        2.000000     67.000000     70.000000     69.000000
# 75%        3.000000     78.000000     80.000000     79.000000
# max        7.000000    100.000000    100.000000    100.000000

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %% [markdown]
# # EDA- Exploratory data analysis

# %% [markdown]
# ## Gender Distribution

# %%
ax=sns.countplot(x="Gender",data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# *From the above charts we analyse that number of female is slightly higher than male*

# %% [markdown]
# *from the above chart we analyse that group C have the higher numbers of others groups*

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %% [markdown]
# ## Parent Education

# %%
parentedu=df.ParentEduc.value_counts().reset_index()
parentedu
# Out:
#            ParentEduc  count
# 0        some college   6633
# 1         high school   5687
# 2  associate's degree   5550
# 3    some high school   5517
# 4   bachelor's degree   3386
# 5     master's degree   2023

# %%
ax=sns.barplot(x="ParentEduc",y="count",data=parentedu,saturation=100)
for bars in ax.containers:
    ax.bar_label(bars)
sns.set(rc={'figure.figsize':(12,5)})
plt.title("parent from diffrent background degree's")
# Out:
# Text(0.5, 1.0, "parent from diffrent background degree's")

# %%
df.columns
# Out:
# Index(['Gender', 'EthnicGroup', 'ParentEduc', 'LunchType', 'TestPrep',
#        'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild', 'NrSiblings',
#        'TransportMeans', 'WklyStudyHours', 'MathScore', 'ReadingScore',
#        'WritingScore'],
#       dtype='object')

# %%
gb=df.groupby(["ParentEduc"]).agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})
gb
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.365586     71.124324     70.299099
# bachelor's degree   70.466627     73.062020     73.331069
# high school         64.435731     67.213997     65.421136
# master's degree     72.336134     75.832921     76.356896
# some college        66.390472     69.179708     68.501432
# some high school    62.584013     65.510785     63.632409

# %%
plt.figure(figsize=(5,5))
sns.heatmap(gb,annot=True)
plt.title("Relationship between  Parent Education and student's score  ")


plt.show()

# %% [markdown]
# *from the above charts we analyse that good education of parents have good impact on children*

# %%
gb1=df.groupby(['ParentMaritalStatus']).agg({'MathScore':'mean','ReadingScore':'mean','WritingScore':'mean'})
gb1
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
plt.figure(figsize=(5,5))
sns.heatmap(gb1,annot=True)
plt.title("Relationship between ParentMaritalStatus and student's score")
plt.show()

# %% [markdown]
# *from the above charts we analyse that 'ParentMaritalStatus' have no/negligible impact on student education*

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x="MathScore",data=df)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x="ReadingScore",data=df)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(x="WritingScore",data=df)
plt.show()

# %% [markdown]
# # Ethnic Group Distribution

# %%
ethenic=df.EthnicGroup.value_counts().reset_index()
epg=ethenic["EthnicGroup"]
epc=ethenic["count"]

plt.pie(epc,labels=epg,autopct="%1.2f%%")
plt.title("distribution of ethnic group")
plt.show()

# %% [markdown]
# *from the above charts we analyse that group C have more percentage than others *
